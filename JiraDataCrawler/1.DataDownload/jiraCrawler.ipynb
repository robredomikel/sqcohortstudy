# %% [markdown]
# # Imports

# %%
import requests  # To get the data
import json  # File IO
from time import sleep
import urllib3
urllib3.disable_warnings(urllib3.exceptions.InsecureRequestWarning)
import pandas as pd
import numpy as np
import csv

# %% [markdown]
# # Load Program Data

# %%
# Get list of Jira sources
with open('/home/mikel/Desktop/project1/JiraDataCrawler/jira_data_sources.json') as f:
    jira_data_sources = json.load(f)

INVALID_JIRAS = ['Mindville', 'MariaDB']

# %% [markdown]
# # Investigate Jira Data Accessibility

# %%
def check_jira_url(jira_url):
    print('')
    print(f"💡 Check Jira: {jira_url}")
    print('')
    ## CHECK PROVIDED JIRA URL AVAILABILITY ##
    print(f'Checking Jira url existence with GET: {jira_url}')
    try:
        requests.head(jira_url)
    except ConnectionError:
        print('❌ Provided Jira base url does not exist')
        return
    else:
        print('✅ Provided Jira base url is reachable')
        
    ## CHECK PROVIDED JIRA URL API AVAILABILITY ##
    response = requests.get(jira_url + '/rest/api/2/issuetype')
    print('')
    print(f'Checking Jira api with GET: {response.url}')
    # Check response code
    if response.status_code < 300:
        print('✅ Jira API returned a successful response')
    else:
        print(response.status_code)
        print(response.text)
        print(response.url)
        print('❌ Jira API did not return a successful response')
        return
    
    ## CHECK NUMBER OF ISSUES ##
    response = requests.get(jira_url + '/rest/api/2/search?jql=&maxResults=0')
    print('')
    print(f"Retrieving total issue count with GET: {response.url}")
    # Check response code
    if response.status_code < 300:
        try:
            print(f"Total Number of Issues: {response.json()['total']}")
            print('✅ Jira API returned a successful response')
        except:
            print("JSON ERROR lads!! Carry on!!")
    else:
        print(response.status_code)
        print(response.text)
        print(response.url)
        print('❌ Jira API did not return a successful response')
        return

# %%
# Check all Jira URLs in provided jira_data_sources
for jira_name, jira_obj in jira_data_sources.items():
    
    # Ignore Jiras that we know are now unreachable or empty
    if jira_name in INVALID_JIRAS:
        continue
    
    check_jira_url(jira_obj['jira_url'])
# Out:
# 💡 Check Jira: https://issues.apache.org/jira
#
# Checking Jira url existence with GET: https://issues.apache.org/jira
# ✅ Provided Jira base url is reachable
#
# Checking Jira api with GET: https://issues.apache.org/jira/rest/api/2/issuetype
# ✅ Jira API returned a successful response
#
# Retrieving total issue count with GET: https://issues.apache.org/jira/rest/api/2/search?jql=&maxResults=0
# Total Number of Issues: 1058418
# ✅ Jira API returned a successful response
#
# 💡 Check Jira: https://jira.hyperledger.org
#
# Checking Jira url existence with GET: https://jira.hyperledger.org
# ✅ Provided Jira base url is reachable
#
# Checking Jira api with GET: https://jira.hyperledger.org/rest/api/2/issuetype
# ✅ Jira API returned a successful response
#
# Retrieving total issue count with GET: https://jira.hyperledger.org/rest/api/2/search?jql=&maxResults=0
# Total Number of Issues: 25886
# ✅ Jira API returned a successful response
#
# 💡 Check Jira: https://jira.hpdd.intel.com
#
# Checking Jira url existence with GET: https://jira.hpdd.intel.com
# ✅ Provided Jira base url is reachable
#
# Checking Jira api with GET: https://daosio.atlassian.net/jira/
# ✅ Jira API returned a successful response
#
# Retrieving total issue count with GET: https://daosio.atlassian.net/jira/
# JSON ERROR lads!! Carry on!!
#
# 💡 Check Jira: https://jfrog.com/jira
#
# Checking Jira url existence with GET: https://jfrog.com/jira
# ✅ Provided Jira base url is reachable
#
# Checking Jira api with GET: https://jfrog.atlassian.net//rest/api/2/issuetype
# ✅ Jira API returned a successful response
#
# Retrieving total issue count with GET: https://jfrog.atlassian.net//rest/api/2/search?jql=&maxResults=0
# Total Number of Issues: 15819
# ✅ Jira API returned a successful response
#
# 💡 Check Jira: https://jira.atlassian.com
#
# Checking Jira url existence with GET: https://jira.atlassian.com
# ✅ Provided Jira base url is reachable
#
# Checking Jira api with GET: https://jira.atlassian.com/rest/api/2/issuetype
# ✅ Jira API returned a successful response
#
# Retrieving total issue count with GET: https://jira.atlassian.com/rest/api/2/search?jql=&maxResults=0
# Total Number of Issues: 290621
# ✅ Jira API returned a successful response
#
# 💡 Check Jira: https://ecosystem.atlassian.net
#
# Checking Jira url existence with GET: https://ecosystem.atlassian.net
# ✅ Provided Jira base url is reachable
#
# Checking Jira api with GET: https://ecosystem.atlassian.net/rest/api/2/issuetype
# ✅ Jira API returned a successful response
#
# Retrieving total issue count with GET: https://ecosystem.atlassian.net/rest/api/2/search?jql=&maxResults=0
# Total Number of Issues: 45972
# ✅ Jira API returned a successful response
#
# 💡 Check Jira: https://bugs.mojang.com
#
# Checking Jira url existence with GET: https://bugs.mojang.com
# ✅ Provided Jira base url is reachable
#
# Checking Jira api with GET: https://bugs.mojang.com/rest/api/2/issuetype
# ✅ Jira API returned a successful response
#
# Retrieving total issue count with GET: https://bugs.mojang.com/rest/api/2/search?jql=&maxResults=0
# Total Number of Issues: 439545
# ✅ Jira API returned a successful response
#
# 💡 Check Jira: https://jira.mongodb.org
#
# Checking Jira url existence with GET: https://jira.mongodb.org
# ✅ Provided Jira base url is reachable
#
# Checking Jira api with GET: https://jira.mongodb.org/rest/api/2/issuetype
# ✅ Jira API returned a successful response
#
# Retrieving total issue count with GET: https://jira.mongodb.org/rest/api/2/search?jql=&maxResults=0
# Total Number of Issues: 161863
# ✅ Jira API returned a successful response
#
# 💡 Check Jira: https://bugreports.qt.io
#
# Checking Jira url existence with GET: https://bugreports.qt.io
# ✅ Provided Jira base url is reachable
#
# Checking Jira api with GET: https://bugreports.qt.io/rest/api/2/issuetype
# ✅ Jira API returned a successful response
#
# Retrieving total issue count with GET: https://bugreports.qt.io/rest/api/2/search?jql=&maxResults=0
# Total Number of Issues: 166752
# ✅ Jira API returned a successful response
#
# 💡 Check Jira: https://issues.redhat.com
#
# Checking Jira url existence with GET: https://issues.redhat.com
# ✅ Provided Jira base url is reachable
#
# Checking Jira api with GET: https://issues.redhat.com/rest/api/2/issuetype
# ✅ Jira API returned a successful response
#
# Retrieving total issue count with GET: https://issues.redhat.com/rest/api/2/search?jql=&maxResults=0
# Total Number of Issues: 405648
# ✅ Jira API returned a successful response
#
# 💡 Check Jira: https://jira.sakaiproject.org
#
# Checking Jira url existence with GET: https://jira.sakaiproject.org
# ✅ Provided Jira base url is reachable
#
# Checking Jira api with GET: https://sakaiproject.atlassian.net/rest/api/2/issuetype
# ✅ Jira API returned a successful response
#
# Retrieving total issue count with GET: https://sakaiproject.atlassian.net/rest/api/2/search?jql=&maxResults=0
# Total Number of Issues: 52345
# ✅ Jira API returned a successful response
#
# 💡 Check Jira: https://jira.secondlife.com
#
# Checking Jira url existence with GET: https://jira.secondlife.com
# ✅ Provided Jira base url is reachable
#
# Checking Jira api with GET: https://jira.secondlife.com/rest/api/2/issuetype
# ✅ Jira API returned a successful response
#
# Retrieving total issue count with GET: https://jira.secondlife.com/rest/api/2/search?jql=&maxResults=0
# Total Number of Issues: 1887
# ✅ Jira API returned a successful response
#
# 💡 Check Jira: https://issues.sonatype.org
#
# Checking Jira url existence with GET: https://issues.sonatype.org
# ✅ Provided Jira base url is reachable
#
# Checking Jira api with GET: https://issues.sonatype.org/rest/api/2/issuetype
# ✅ Jira API returned a successful response
#
# Retrieving total issue count with GET: https://issues.sonatype.org/rest/api/2/search?jql=&maxResults=0
# Total Number of Issues: 99768
# ✅ Jira API returned a successful response
#
# 💡 Check Jira: https://jira.spring.io
#
# Checking Jira url existence with GET: https://jira.spring.io
# ✅ Provided Jira base url is reachable
#
# Checking Jira api with GET: https://jira.spring.io/rest/api/2/issuetype
# ✅ Jira API returned a successful response
#
# Retrieving total issue count with GET: https://jira.spring.io/rest/api/2/search?jql=&maxResults=0
# Total Number of Issues: 1537
# ✅ Jira API returned a successful response

# %% [markdown]
# # Download Jira Data

# %%
def format_duration(start_time, end_time):
    # Get the total seconds of the duration
    seconds = end_time - start_time
    # Calculate the other time 
    milliseconds = int((seconds % 1) * 10000)
    minutes = int(seconds / 60)
    hours   = int(minutes / 60)
    # Trim the values to fit in their appopriate slots
    display_minutes = int(minutes % 60)
    display_seconds = int(seconds % 60)

    return f"{hours:02}:{display_minutes:02}:{display_seconds:02}.{milliseconds:04}"

# %%
# Write the result to a JSON
output_json = {}

for jira_name, jira_data in jira_data_sources.items():
    
    # Ignore Jiras that we know are now unreachable or empty
    if jira_name in INVALID_JIRAS:
        continue

    # Build the URL to get the information from
    jira_issuetype_url = jira_data['jira_url'] + '/rest/api/2/issuetype'

    try:
        # Get the issuetype definitions
        documented_issuetypes = {

            issuetype['name']: issuetype
            for issuetype in requests.get(jira_issuetype_url).json()
        }
    except:
        pass

        # Save the information
    output_json[jira_name] = documented_issuetypes

# Write JSON to file
with open('jira_issuetype_information.json', 'w', encoding='utf-8') as json_file:
    json.dump(output_json, json_file, ensure_ascii=False, indent=4)

# %%
# Write the result to a JSON
output_json = {}

for jira_name, jira_data in jira_data_sources.items():
    
    # Ignore Jiras that we know are now unreachable or empty
    if jira_name in INVALID_JIRAS:
        continue

    # Build the URL to get the information from
    jira_issuelinktype_url = jira_data['jira_url'] + '/rest/api/2/issueLinkType'

    try:
        # Get the issuelinktype definitions
        documented_issuelinktypes = {
            issuelinktype['name']: issuelinktype
            for issuelinktype in requests.get(jira_issuelinktype_url).json()['issueLinkTypes']
        }
    except:
        pass

    # Save the information
    output_json[jira_name] = documented_issuelinktypes

# Write JSON to file
with open('jira_issuelinktype_information.json', 'w', encoding='utf-8') as json_file:
    json.dump(output_json, json_file, ensure_ascii=False, indent=4)

# %% [markdown]
# # JIRA REPOSITORY CRAWLER
# ## Explanation of what it does, and how it's done.
# Param: Name of the project to crawl
# Process: REST API of the Jira repo request with the selected attributes from projects' issues.
# Returns: Writes a csv file with the downloaded data.

# %%
# API call for the list of projects from Jira Apache projects.
delta = requests.get("https://issues.apache.org/jira/rest/api/2/project")
jiraProjects = delta.json()

# %%
# CLEANING: Ignores the projects in the attic + stores the names of the rest.

activeProjects = [] # Projects that are not retired and have a clear category.

for project in jiraProjects: # Where all the projects handled with Jira are stored

    try:
        category = project['projectCategory']['name']
    except KeyError: # If the project doesn't have a category section, bad signal!
        continue

    if category == "Retired": # If the project is in the attic.
        continue
    else:
        activeProjects.append(project)

# %%
# MAIN FUNCTION
def jiraCrawler(projectLinkName, responseError):

    # Fixed parameters for the API call search query.
    startAt = 0
    maxResult = 100

    # list gathering all issue dictionaries.
    projectissuedataitems = []

    # List of attributes to be downloaded.
    issue_feature_list = ['project_ID', 'project_name', 'issue_ID', 'issue_type_ID', 'issue_type_name', 'key', 'user_login', 'state', 'state_key', 'issue_link', 'created_at', 'updated_at', 'resolution_at', 'active_time', 'title', 'body', 'description', 'watchcount']

    # Creation of the CSV file with the header.
    with open(f"/home/mikel/Desktop/project1/JiraDataCrawler/1.DataDownload/jiraProjectIssues/{projectLinkName}.csv", 'w', encoding='utf-8') as file:
        writer = csv.writer(file, delimiter=',')
        writer.writerow([x for x in issue_feature_list])

    # It will loop until there's no more issues to crawl.
    while 1 == 1:

        # Link for the API call.
        jiraLink = "https://issues.apache.org/jira/rest/api/2/" + f"search?jql=project={projectLinkName}&startAt={startAt}&maxResults={maxResult}"

        # Request call.
        theResult = requests.get(jiraLink)

        # Control check to omit problematic requests:
        if theResult.status_code != 200:
            #responseError.append(projectLinkName)
            break
        # List of issues from the project.
        theItemListPerPage = theResult.json()['issues']

        if len(theItemListPerPage) == 0:
            break
        else: # If there're issues in the fetched json, the process starts.
            print(f"API call status: {theResult.headers['Keep-Alive']}")
            print(f"Length of issues: {len(theResult.json()['issues'])}")
            print(projectLinkName+' '+f"Starting at: {startAt}, Max results: {maxResult}")
            for item in theItemListPerPage:
                issueitem = {}
                # If the issue was closed before sonarQube existed (created on 2006), then it directly means
                # they didn't use SQ at all for that issue. Hence we first check that.
                resolutionDate = pd.Timestamp(item['fields']['resolutiondate'])
                if resolutionDate is not None and resolutionDate < pd.Timestamp("2006-01-01").tz_localize('UTC'):
                    responseError.append(item['id'])
                    continue

                issueitem['project_ID'] = item['fields']['project']['id']
                issueitem['project_name'] = item['fields']['project']['name']
                issueitem['issue_ID'] = item['id']
                issueitem['issue_type_ID'] = item['fields']['issuetype']['id']
                issueitem['issue_type_name'] = item['fields']['issuetype']['name']
                issueitem['key'] = item['key'] # Somehow like 'number' in Github
                try:
                    issueitem['user_login'] = item['fields']['creator']['name']
                except TypeError:
                    issueitem['user_login'] = 'unassigned'
                issueitem['state'] = item['fields']['status']['name']
                issueitem['state_key'] = item['fields']['status']['statusCategory']['key']
                issueitem['issue_link'] = item['self']
                issueitem['created_at'] = pd.Timestamp(item['fields']['created'])

                if item['fields']['updated'] == None:
                    issueitem['updated_at'] = np.NaN
                else:
                    issueitem['updated_at'] = pd.Timestamp(item['fields']['updated'])

                # There's a resolution date but it can be tricky to understand.
                # An issue can have a resolution date when being resolved and/or closed.
                if resolutionDate == None:
                    issueitem['resolution_at'] = np.NaN
                    issueitem['active_time(segs)'] = pd.Timedelta(issueitem['updated_at'] - issueitem['created_at']).total_seconds()
                else:
                    issueitem['resolution_at'] = resolutionDate
                    issueitem['active_time'] = pd.Timedelta(resolutionDate - issueitem['created_at']).total_seconds()

                issueitem['title'] = item['fields']['issuetype']['description']
                issueitem['body'] = item['fields']['status']['description']
                issueitem['description'] = item['fields']['description']
                issueitem['watchcount'] = item['fields']['watches']['watchCount']

                # All issues are stored in this list.
                projectissuedataitems.append(issueitem)
                # f"/home/mikel/Desktop/project1/JiraDataCrawler/1.DataDownload/jiraProjectIssues/{projectLinkName}.csv"
                with open(f"/home/mikel/Desktop/project1/JiraDataCrawler/1.DataDownload/jiraProjectIssues/{projectLinkName}.csv", 'a', encoding='utf-8') as file:
                    writer = csv.writer(file, delimiter=',')
                    writer.writerow([issueitem[x] for x in issue_feature_list])

            if startAt == 0:
                startAt += (maxResult)
            else:
                startAt += maxResult

    print(f"{projectLinkName} download completed!")

    return responseError

# %%
# Error of bad request cases fixed.
# Once the download is done, remove the index of project 'exec' value from the list "active projects"
errorRequest = 0
for project in activeProjects:
    jiraCrawler(project['key'].lower(), errorRequest)
    sleep(15) # Sleep 15 from project to project for timeouts
# Out:
# exec download completed!
# API call status: timeout=15, max=100
# Length of issues: 100
# fileupload Starting at: 0, Max results: 100
# API call status: timeout=15, max=100
# Length of issues: 100
# fileupload Starting at: 100, Max results: 100
# API call status: timeout=15, max=100
# Length of issues: 100
# fileupload Starting at: 200, Max results: 100
# API call status: timeout=15, max=100
# Length of issues: 44
# fileupload Starting at: 300, Max results: 100
# fileupload download completed!
# API call status: timeout=15, max=100
# Length of issues: 31
# functor Starting at: 0, Max results: 100
# functor download completed!
# API call status: timeout=15, max=100
# Length of issues: 100
# geometry Starting at: 0, Max results: 100
# API call status: timeout=15, max=100
# Length of issues: 35
# geometry Starting at: 100, Max results: 100
# geometry download completed!
# API call status: timeout=15, max=100
# Length of issues: 100
# imaging Starting at: 0, Max results: 100
# API call status: timeout=15, max=100
# Length of issues: 100
# imaging Starting at: 100, Max results: 100
# API call status: timeout=15, max=100
# Length of issues: 100
# imaging Starting at: 200, Max results: 100
# API call status: timeout=15, max=100
# Length of issues: 45
# imaging Starting at: 300, Max results: 100
# imaging download completed!
# API call status: timeout=15, max=100
# Length of issues: 100
# io Starting at: 0, Max results: 100
# API call status: timeout=15, max=100
# Length of issues: 100
# io Starting at: 100, Max results: 100
# API call status: timeout=15, max=100
# Length of issues: 100
# io Starting at: 200, Max results: 100
# API call status: timeout=15, max=100
# Length of issues: 100
# io Starting at: 300, Max results: 100
# API call status: timeout=15, max=100
# Length of issues: 100
# io Starting at: 400, Max results: 100
# API call status: timeout=15, max=100
# Length of issues: 100
# io Starting at: 500, Max results: 100
# API call status: timeout=15, max=100
# Length of issues: 100
# io Starting at: 600, Max results: 100
# API call status: timeout=15, max=100
# Length of issues: 73
# io Starting at: 700, Max results: 100
# io download completed!
# API call status: timeout=15, max=100
# Length of issues: 79
# jci Starting at: 0, Max results: 100
# jci download completed!
# API call status: timeout=15, max=100
# Length of issues: 100
# jcs Starting at: 0, Max results: 100
# API call status: timeout=15, max=100
# Length of issues: 100
# jcs Starting at: 100, Max results: 100
# API call status: timeout=15, max=100
# Length of issues: 31
# jcs Starting at: 200, Max results: 100
# jcs download completed!
# API call status: timeout=15, max=100
# Length of issues: 100
# jelly Starting at: 0, Max results: 100
# API call status: timeout=15, max=100
# Length of issues: 100
# jelly Starting at: 100, Max results: 100
# API call status: timeout=15, max=100
# Length of issues: 91
# jelly Starting at: 200, Max results: 100
# jelly download completed!
# API call status: timeout=15, max=100
# Length of issues: 100
# jexl Starting at: 0, Max results: 100
# API call status: timeout=15, max=100
# Length of issues: 100
# jexl Starting at: 100, Max results: 100
# API call status: timeout=15, max=100
# Length of issues: 100
# jexl Starting at: 200, Max results: 100
# API call status: timeout=15, max=100
# Length of issues: 90
# jexl Starting at: 300, Max results: 100
# jexl download completed!
# API call status: timeout=15, max=100
# Length of issues: 100
# jxpath Starting at: 0, Max results: 100
# API call status: timeout=15, max=100
# Length of issues: 100
# jxpath Starting at: 100, Max results: 100
# jxpath download completed!
# API call status: timeout=15, max=100
# Length of issues: 100
# lang Starting at: 0, Max results: 100
# API call status: timeout=15, max=100
# Length of issues: 100
# lang Starting at: 100, Max results: 100
# API call status: timeout=15, max=100
# Length of issues: 100
# lang Starting at: 200, Max results: 100
# API call status: timeout=15, max=100
# Length of issues: 100
# lang Starting at: 300, Max results: 100
# API call status: timeout=15, max=100
# Length of issues: 100
# lang Starting at: 400, Max results: 100
# API call status: timeout=15, max=100
# Length of issues: 100
# lang Starting at: 500, Max results: 100
# API call status: timeout=15, max=100
# Length of issues: 100
# lang Starting at: 600, Max results: 100
# API call status: timeout=15, max=100
# Length of issues: 100
# lang Starting at: 700, Max results: 100
# API call status: timeout=15, max=100
# Length of issues: 100
# lang Starting at: 800, Max results: 100
# API call status: timeout=15, max=100
# Length of issues: 100
# lang Starting at: 900, Max results: 100
# API call status: timeout=15, max=100
# Length of issues: 100
# lang Starting at: 1000, Max results: 100
# API call status: timeout=15, max=100
# Length of issues: 100
# lang Starting at: 1100, Max results: 100
# API call status: timeout=15, max=100
# Length of issues: 100
# lang Starting at: 1200, Max results: 100
# API call status: timeout=15, max=100
# Length of issues: 100
# lang Starting at: 1300, Max results: 100
# API call status: timeout=15, max=100
# Length of issues: 100
# lang Starting at: 1400, Max results: 100
# API call status: timeout=15, max=100
# Length of issues: 100
# lang Starting at: 1500, Max results: 100
# API call status: timeout=15, max=100
# Length of issues: 56
# lang Starting at: 1600, Max results: 100
# lang download completed!
# API call status: timeout=15, max=100
# Length of issues: 12
# launcher Starting at: 0, Max results: 100
# launcher download completed!
# API call status: timeout=15, max=100
# Length of issues: 100
# logging Starting at: 0, Max results: 100
# API call status: timeout=15, max=100
# Length of issues: 79
# logging Starting at: 100, Max results: 100
# logging download completed!
# API call status: timeout=15, max=100
# Length of issues: 100
# math Starting at: 0, Max results: 100
# API call status: timeout=15, max=100
# Length of issues: 100
# math Starting at: 100, Max results: 100
# API call status: timeout=15, max=100
# Length of issues: 100
# math Starting at: 200, Max results: 100
# API call status: timeout=15, max=100
# Length of issues: 100
# math Starting at: 300, Max results: 100
# API call status: timeout=15, max=100
# Length of issues: 100
# math Starting at: 400, Max results: 100
# API call status: timeout=15, max=100
# Length of issues: 100
# math Starting at: 500, Max results: 100
# API call status: timeout=15, max=100
# Length of issues: 100
# math Starting at: 600, Max results: 100
# API call status: timeout=15, max=100
# Length of issues: 100
# math Starting at: 700, Max results: 100
# API call status: timeout=15, max=100
# Length of issues: 100
# math Starting at: 800, Max results: 100
# API call status: timeout=15, max=100
# Length of issues: 100
# math Starting at: 900, Max results: 100
# API call status: timeout=15, max=100
# Length of issues: 100
# math Starting at: 1000, Max results: 100
# API call status: timeout=15, max=100
# Length of issues: 100
# math Starting at: 1100, Max results: 100
# API call status: timeout=15, max=100
# Length of issues: 100
# math Starting at: 1200, Max results: 100
# API call status: timeout=15, max=100
# Length of issues: 100
# math Starting at: 1300, Max results: 100
# API call status: timeout=15, max=100
# Length of issues: 100
# math Starting at: 1400, Max results: 100
# API call status: timeout=15, max=100
# Length of issues: 100
# math Starting at: 1500, Max results: 100
# API call status: timeout=15, max=100
# Length of issues: 44
# math Starting at: 1600, Max results: 100
# math download completed!
# API call status: timeout=15, max=100
# Length of issues: 32
# modeler Starting at: 0, Max results: 100
# modeler download completed!
# API call status: timeout=15, max=100
# Length of issues: 100
# net Starting at: 0, Max results: 100
# API call status: timeout=15, max=100
# Length of issues: 100
# net Starting at: 100, Max results: 100
# API call status: timeout=15, max=100
# Length of issues: 100
# net Starting at: 200, Max results: 100
# API call status: timeout=15, max=100
# Length of issues: 100
# net Starting at: 300, Max results: 100
# API call status: timeout=15, max=100
# Length of issues: 100
# net Starting at: 400, Max results: 100
# API call status: timeout=15, max=100
# Length of issues: 100
# net Starting at: 500, Max results: 100
# API call status: timeout=15, max=100
# Length of issues: 100
# net Starting at: 600, Max results: 100
# API call status: timeout=15, max=100
# Length of issues: 8
# net Starting at: 700, Max results: 100
# net download completed!
# API call status: timeout=15, max=100
# Length of issues: 100
# numbers Starting at: 0, Max results: 100
# API call status: timeout=15, max=100
# Length of issues: 90
# numbers Starting at: 100, Max results: 100
# numbers download completed!
# API call status: timeout=15, max=100
# Length of issues: 100
# ognl Starting at: 0, Max results: 100
# API call status: timeout=15, max=100
# Length of issues: 100
# ognl Starting at: 100, Max results: 100
# API call status: timeout=15, max=100
# Length of issues: 61
# ognl Starting at: 200, Max results: 100
# ognl download completed!
# API call status: timeout=15, max=100
# Length of issues: 100
# pool Starting at: 0, Max results: 100
# API call status: timeout=15, max=100
# Length of issues: 100
# pool Starting at: 100, Max results: 100
# API call status: timeout=15, max=100
# Length of issues: 100
# pool Starting at: 200, Max results: 100
# API call status: timeout=15, max=100
# Length of issues: 90
# pool Starting at: 300, Max results: 100
# pool download completed!
# API call status: timeout=15, max=100
# Length of issues: 13
# primitives Starting at: 0, Max results: 100
# primitives download completed!
# API call status: timeout=15, max=100
# Length of issues: 28
# proxy Starting at: 0, Max results: 100
# proxy download completed!
# API call status: timeout=15, max=100
# Length of issues: 41
# resources Starting at: 0, Max results: 100
# resources download completed!
# API call status: timeout=15, max=100
# Length of issues: 100
# rng Starting at: 0, Max results: 100
# API call status: timeout=15, max=100
# Length of issues: 84
# rng Starting at: 100, Max results: 100
# rng download completed!
# API call status: timeout=15, max=100
# Length of issues: 100
# sandbox Starting at: 0, Max results: 100
# API call status: timeout=15, max=100
# Length of issues: 100
# sandbox Starting at: 100, Max results: 100
# API call status: timeout=15, max=100
# Length of issues: 66
# sandbox Starting at: 200, Max results: 100
# sandbox download completed!
# sanselan download completed!
# API call status: timeout=15, max=100
# Length of issues: 100
# scxml Starting at: 0, Max results: 100
# API call status: timeout=15, max=100
# Length of issues: 100
# scxml Starting at: 100, Max results: 100
# API call status: timeout=15, max=100
# Length of issues: 88
# scxml Starting at: 200, Max results: 100
# scxml download completed!
# API call status: timeout=15, max=100
# Length of issues: 58
# statistics Starting at: 0, Max results: 100
# statistics download completed!
# API call status: timeout=15, max=100
# Length of issues: 100
# text Starting at: 0, Max results: 100
# API call status: timeout=15, max=100
# Length of issues: 100
# text Starting at: 100, Max results: 100
# API call status: timeout=15, max=100
# Length of issues: 14
# text Starting at: 200, Max results: 100
# text download completed!
# transaction download completed!
# API call status: timeout=15, max=100
# Length of issues: 100
# validator Starting at: 0, Max results: 100
# API call status: timeout=15, max=100
# Length of issues: 100
# validator Starting at: 100, Max results: 100
# API call status: timeout=15, max=100
# Length of issues: 100
# validator Starting at: 200, Max results: 100
# API call status: timeout=15, max=100
# Length of issues: 100
# validator Starting at: 300, Max results: 100
# API call status: timeout=15, max=100
# Length of issues: 87
# validator Starting at: 400, Max results: 100
# validator download completed!
# API call status: timeout=15, max=100
# Length of issues: 100
# vfs Starting at: 0, Max results: 100
# API call status: timeout=15, max=100
# Length of issues: 100
# vfs Starting at: 100, Max results: 100
# API call status: timeout=15, max=100
# Length of issues: 100
# vfs Starting at: 200, Max results: 100
# API call status: timeout=15, max=100
# Length of issues: 100
# vfs Starting at: 300, Max results: 100
# API call status: timeout=15, max=100
# Length of issues: 100
# vfs Starting at: 400, Max results: 100
# API call status: timeout=15, max=100
# Length of issues: 100
# vfs Starting at: 500, Max results: 100
# API call status: timeout=15, max=100
# Length of issues: 100
# vfs Starting at: 600, Max results: 100
# API call status: timeout=15, max=100
# Length of issues: 100
# vfs Starting at: 700, Max results: 100
# API call status: timeout=15, max=100
# Length of issues: 28
# vfs Starting at: 800, Max results: 100
# vfs download completed!
# API call status: timeout=15, max=100
# Length of issues: 26
# weaver Starting at: 0, Max results: 100
# weaver download completed!
# API call status: timeout=15, max=100
# Length of issues: 100
# comdev Starting at: 0, Max results: 100
# API call status: timeout=15, max=100
# Length of issues: 100
# comdev Starting at: 100, Max results: 100
# API call status: timeout=15, max=100
# Length of issues: 100
# comdev Starting at: 200, Max results: 100
# API call status: timeout=15, max=100
# Length of issues: 100
# comdev Starting at: 300, Max results: 100
# API call status: timeout=15, max=100
# Length of issues: 59
# comdev Starting at: 400, Max results: 100
# comdev download completed!
# API call status: timeout=15, max=100
# Length of issues: 100
# continuum Starting at: 0, Max results: 100
# API call status: timeout=15, max=100
# Length of issues: 100
# continuum Starting at: 100, Max results: 100
# API call status: timeout=15, max=100
# Length of issues: 100
# continuum Starting at: 200, Max results: 100
# API call status: timeout=15, max=100
# Length of issues: 100
# continuum Starting at: 300, Max results: 100
# API call status: timeout=15, max=100
# Length of issues: 100
# continuum Starting at: 400, Max results: 100
# API call status: timeout=15, max=100
# Length of issues: 100
# continuum Starting at: 500, Max results: 100
# API call status: timeout=15, max=100
# Length of issues: 100
# continuum Starting at: 600, Max results: 100
# API call status: timeout=15, max=100
# Length of issues: 100
# continuum Starting at: 700, Max results: 100
# API call status: timeout=15, max=100
# Length of issues: 100
# continuum Starting at: 800, Max results: 100
# API call status: timeout=15, max=100
# Length of issues: 100
# continuum Starting at: 900, Max results: 100
# API call status: timeout=15, max=100
# Length of issues: 100
# continuum Starting at: 1000, Max results: 100
# API call status: timeout=15, max=100
# Length of issues: 100
# continuum Starting at: 1100, Max results: 100
# API call status: timeout=15, max=100
# Length of issues: 100
# continuum Starting at: 1200, Max results: 100
# API call status: timeout=15, max=100
# Length of issues: 100
# continuum Starting at: 1300, Max results: 100
# API call status: timeout=15, max=100
# Length of issues: 100
# continuum Starting at: 1400, Max results: 100
# API call status: timeout=15, max=100
# Length of issues: 100
# continuum Starting at: 1500, Max results: 100
# API call status: timeout=15, max=100
# Length of issues: 100
# continuum Starting at: 1600, Max results: 100
# API call status: timeout=15, max=100
# Length of issues: 100
# continuum Starting at: 1700, Max results: 100
# API call status: timeout=15, max=100
# Length of issues: 100
# continuum Starting at: 1800, Max results: 100
# API call status: timeout=15, max=100
# Length of issues: 100
# continuum Starting at: 1900, Max results: 100
# API call status: timeout=15, max=100
# Length of issues: 100
# continuum Starting at: 2000, Max results: 100
# API call status: timeout=15, max=100
# Length of issues: 100
# continuum Starting at: 2100, Max results: 100
# API call status: timeout=15, max=100
# Length of issues: 100
# continuum Starting at: 2200, Max results: 100
# API call status: timeout=15, max=100
# Length of issues: 100
# continuum Starting at: 2300, Max results: 100
# API call status: timeout=15, max=100
# Length of issues: 100
# continuum Starting at: 2400, Max results: 100
# API call status: timeout=15, max=100
# Length of issues: 100
# continuum Starting at: 2500, Max results: 100
# API call status: timeout=15, max=100
# Length of issues: 100
# continuum Starting at: 2600, Max results: 100
# API call status: timeout=15, max=100
# Length of issues: 24
# continuum Starting at: 2700, Max results: 100
# continuum download completed!
# API call status: timeout=15, max=100
# Length of issues: 100
# couchdb Starting at: 0, Max results: 100
# API call status: timeout=15, max=100
# Length of issues: 100
# couchdb Starting at: 100, Max results: 100
# API call status: timeout=15, max=100
# Length of issues: 100
# couchdb Starting at: 200, Max results: 100
# API call status: timeout=15, max=100
# Length of issues: 100
# couchdb Starting at: 300, Max results: 100
# API call status: timeout=15, max=100
# Length of issues: 100
# couchdb Starting at: 400, Max results: 100
# API call status: timeout=15, max=100
# Length of issues: 100
# couchdb Starting at: 500, Max results: 100
# API call status: timeout=15, max=100
# Length of issues: 100
# couchdb Starting at: 600, Max results: 100
# API call status: timeout=15, max=100
# Length of issues: 100
# couchdb Starting at: 700, Max results: 100
# API call status: timeout=15, max=100
# Length of issues: 100
# couchdb Starting at: 800, Max results: 100
# API call status: timeout=15, max=100
# Length of issues: 100
# couchdb Starting at: 900, Max results: 100
# API call status: timeout=15, max=100
# Length of issues: 100
# couchdb Starting at: 1000, Max results: 100
# API call status: timeout=15, max=100
# Length of issues: 100
# couchdb Starting at: 1100, Max results: 100
# API call status: timeout=15, max=100
# Length of issues: 100
# couchdb Starting at: 1200, Max results: 100
# API call status: timeout=15, max=100
# Length of issues: 100
# couchdb Starting at: 1300, Max results: 100
# API call status: timeout=15, max=100
# Length of issues: 100
# couchdb Starting at: 1400, Max results: 100
# API call status: timeout=15, max=100
# Length of issues: 100
# couchdb Starting at: 1500, Max results: 100
# API call status: timeout=15, max=100
# Length of issues: 100
# couchdb Starting at: 1600, Max results: 100
# API call status: timeout=15, max=100
# Length of issues: 100
# couchdb Starting at: 1700, Max results: 100
# API call status: timeout=15, max=100
# Length of issues: 100
# couchdb Starting at: 1800, Max results: 100
# API call status: timeout=15, max=100
# Length of issues: 100
# couchdb Starting at: 1900, Max results: 100
# API call status: timeout=15, max=100
# Length of issues: 100
# couchdb Starting at: 2000, Max results: 100
# API call status: timeout=15, max=100
# Length of issues: 100
# couchdb Starting at: 2100, Max results: 100
# API call status: timeout=15, max=100
# Length of issues: 100
# couchdb Starting at: 2200, Max results: 100
# API call status: timeout=15, max=100
# Length of issues: 100
# couchdb Starting at: 2300, Max results: 100
# API call status: timeout=15, max=100
# Length of issues: 100
# couchdb Starting at: 2400, Max results: 100
# API call status: timeout=15, max=100
# Length of issues: 100
# couchdb Starting at: 2500, Max results: 100
# API call status: timeout=15, max=100
# Length of issues: 100
# couchdb Starting at: 2600, Max results: 100
# API call status: timeout=15, max=100
# Length of issues: 100
# couchdb Starting at: 2700, Max results: 100
# API call status: timeout=15, max=100
# Length of issues: 100
# couchdb Starting at: 2800, Max results: 100
# API call status: timeout=15, max=100
# Length of issues: 100
# couchdb Starting at: 2900, Max results: 100
# API call status: timeout=15, max=100
# Length of issues: 100
# couchdb Starting at: 3000, Max results: 100
# API call status: timeout=15, max=100
# Length of issues: 100
# couchdb Starting at: 3100, Max results: 100
# API call status: timeout=15, max=100
# Length of issues: 92
# couchdb Starting at: 3200, Max results: 100
# couchdb download completed!
# API call status: timeout=15, max=100
# Length of issues: 100
# ctakes Starting at: 0, Max results: 100
# API call status: timeout=15, max=100
# Length of issues: 100
# ctakes Starting at: 100, Max results: 100
# API call status: timeout=15, max=100
# Length of issues: 100
# ctakes Starting at: 200, Max results: 100
# API call status: timeout=15, max=100
# Length of issues: 100
# ctakes Starting at: 300, Max results: 100
# API call status: timeout=15, max=100
# Length of issues: 100
# ctakes Starting at: 400, Max results: 100
# API call status: timeout=15, max=100
# Length of issues: 64
# ctakes Starting at: 500, Max results: 100
# ctakes download completed!
# API call status: timeout=15, max=100
# Length of issues: 100
# cxf Starting at: 0, Max results: 100
# API call status: timeout=15, max=100
# Length of issues: 100
# cxf Starting at: 100, Max results: 100
# API call status: timeout=15, max=100
# Length of issues: 100
# cxf Starting at: 200, Max results: 100
# API call status: timeout=15, max=100
# Length of issues: 100
# cxf Starting at: 300, Max results: 100
# API call status: timeout=15, max=100
# Length of issues: 100
# cxf Starting at: 400, Max results: 100
# API call status: timeout=15, max=100
# Length of issues: 100
# cxf Starting at: 500, Max results: 100
# API call status: timeout=15, max=100
# Length of issues: 100
# cxf Starting at: 600, Max results: 100
# API call status: timeout=15, max=100
# Length of issues: 100
# cxf Starting at: 700, Max results: 100
# API call status: timeout=15, max=100
# Length of issues: 100
# cxf Starting at: 800, Max results: 100
# API call status: timeout=15, max=100
# Length of issues: 100
# cxf Starting at: 900, Max results: 100
# API call status: timeout=15, max=100
# Length of issues: 100
# cxf Starting at: 1000, Max results: 100
# API call status: timeout=15, max=100
# Length of issues: 100
# cxf Starting at: 1100, Max results: 100
# API call status: timeout=15, max=100
# Length of issues: 100
# cxf Starting at: 1200, Max results: 100
# API call status: timeout=15, max=100
# Length of issues: 100
# cxf Starting at: 1300, Max results: 100
# API call status: timeout=15, max=100
# Length of issues: 100
# cxf Starting at: 1400, Max results: 100
# API call status: timeout=15, max=100
# Length of issues: 100
# cxf Starting at: 1500, Max results: 100
# API call status: timeout=15, max=100
# Length of issues: 100
# cxf Starting at: 1600, Max results: 100
# API call status: timeout=15, max=100
# Length of issues: 100
# cxf Starting at: 1700, Max results: 100
# API call status: timeout=15, max=100
# Length of issues: 100
# cxf Starting at: 1800, Max results: 100
# API call status: timeout=15, max=100
# Length of issues: 100
# cxf Starting at: 1900, Max results: 100
# API call status: timeout=15, max=100
# Length of issues: 100
# cxf Starting at: 2000, Max results: 100
# API call status: timeout=15, max=100
# Length of issues: 100
# cxf Starting at: 2100, Max results: 100
# API call status: timeout=15, max=100
# Length of issues: 100
# cxf Starting at: 2200, Max results: 100
# API call status: timeout=15, max=100
# Length of issues: 100
# cxf Starting at: 2300, Max results: 100
# API call status: timeout=15, max=100
# Length of issues: 100
# cxf Starting at: 2400, Max results: 100
# API call status: timeout=15, max=100
# Length of issues: 100
# cxf Starting at: 2500, Max results: 100
# API call status: timeout=15, max=100
# Length of issues: 100
# cxf Starting at: 2600, Max results: 100
# API call status: timeout=15, max=100
# Length of issues: 100
# cxf Starting at: 2700, Max results: 100
# API call status: timeout=15, max=100
# Length of issues: 100
# cxf Starting at: 2800, Max results: 100
# API call status: timeout=15, max=100
# Length of issues: 100
# cxf Starting at: 2900, Max results: 100
# API call status: timeout=15, max=100
# Length of issues: 100
# cxf Starting at: 3000, Max results: 100
# API call status: timeout=15, max=100
# Length of issues: 100
# cxf Starting at: 3100, Max results: 100
# API call status: timeout=15, max=100
# Length of issues: 100
# cxf Starting at: 3200, Max results: 100
# API call status: timeout=15, max=100
# Length of issues: 100
# cxf Starting at: 3300, Max results: 100
# API call status: timeout=15, max=100
# Length of issues: 100
# cxf Starting at: 3400, Max results: 100
# API call status: timeout=15, max=100
# Length of issues: 100
# cxf Starting at: 3500, Max results: 100
# API call status: timeout=15, max=100
# Length of issues: 100
# cxf Starting at: 3600, Max results: 100
# API call status: timeout=15, max=100
# Length of issues: 100
# cxf Starting at: 3700, Max results: 100
# API call status: timeout=15, max=100
# Length of issues: 100
# cxf Starting at: 3800, Max results: 100
# API call status: timeout=15, max=100
# Length of issues: 100
# cxf Starting at: 3900, Max results: 100
# API call status: timeout=15, max=100
# Length of issues: 100
# cxf Starting at: 4000, Max results: 100
# API call status: timeout=15, max=100
# Length of issues: 100
# cxf Starting at: 4100, Max results: 100
# API call status: timeout=15, max=100
# Length of issues: 100
# cxf Starting at: 4200, Max results: 100
# API call status: timeout=15, max=100
# Length of issues: 100
# cxf Starting at: 4300, Max results: 100
# API call status: timeout=15, max=100
# Length of issues: 100
# cxf Starting at: 4400, Max results: 100
# API call status: timeout=15, max=100
# Length of issues: 100
# cxf Starting at: 4500, Max results: 100
# API call status: timeout=15, max=100
# Length of issues: 100
# cxf Starting at: 4600, Max results: 100
# API call status: timeout=15, max=100
# Length of issues: 100
# cxf Starting at: 4700, Max results: 100
# API call status: timeout=15, max=100
# Length of issues: 100
# cxf Starting at: 4800, Max results: 100
# API call status: timeout=15, max=100
# Length of issues: 100
# cxf Starting at: 4900, Max results: 100
# API call status: timeout=15, max=100
# Length of issues: 100
# cxf Starting at: 5000, Max results: 100
# API call status: timeout=15, max=100
# Length of issues: 100
# cxf Starting at: 5100, Max results: 100
# API call status: timeout=15, max=100
# Length of issues: 100
# cxf Starting at: 5200, Max results: 100
# API call status: timeout=15, max=100
# Length of issues: 100
# cxf Starting at: 5300, Max results: 100
# API call status: timeout=15, max=100
# Length of issues: 100
# cxf Starting at: 5400, Max results: 100
# API call status: timeout=15, max=100
# Length of issues: 100
# cxf Starting at: 5500, Max results: 100
# API call status: timeout=15, max=100
# Length of issues: 100
# cxf Starting at: 5600, Max results: 100
# API call status: timeout=15, max=100
# Length of issues: 100
# cxf Starting at: 5700, Max results: 100
# API call status: timeout=15, max=100
# Length of issues: 100
# cxf Starting at: 5800, Max results: 100
# API call status: timeout=15, max=100
# Length of issues: 100
# cxf Starting at: 5900, Max results: 100
# API call status: timeout=15, max=100
# Length of issues: 100
# cxf Starting at: 6000, Max results: 100
# API call status: timeout=15, max=100
# Length of issues: 100
# cxf Starting at: 6100, Max results: 100
# API call status: timeout=15, max=100
# Length of issues: 100
# cxf Starting at: 6200, Max results: 100
# API call status: timeout=15, max=100
# Length of issues: 100
# cxf Starting at: 6300, Max results: 100
# API call status: timeout=15, max=100
# Length of issues: 100
# cxf Starting at: 6400, Max results: 100
# API call status: timeout=15, max=100
# Length of issues: 100
# cxf Starting at: 6500, Max results: 100
# API call status: timeout=15, max=100
# Length of issues: 100
# cxf Starting at: 6600, Max results: 100
# API call status: timeout=15, max=100
# Length of issues: 100
# cxf Starting at: 6700, Max results: 100
# API call status: timeout=15, max=100
# Length of issues: 100
# cxf Starting at: 6800, Max results: 100
# API call status: timeout=15, max=100
# Length of issues: 100
# cxf Starting at: 6900, Max results: 100
# API call status: timeout=15, max=100
# Length of issues: 100
# cxf Starting at: 7000, Max results: 100
# API call status: timeout=15, max=100
# Length of issues: 100
# cxf Starting at: 7100, Max results: 100
# API call status: timeout=15, max=100
# Length of issues: 100
# cxf Starting at: 7200, Max results: 100
# API call status: timeout=15, max=100
# Length of issues: 100
# cxf Starting at: 7300, Max results: 100
# API call status: timeout=15, max=100
# Length of issues: 100
# cxf Starting at: 7400, Max results: 100
# API call status: timeout=15, max=100
# Length of issues: 100
# cxf Starting at: 7500, Max results: 100
# API call status: timeout=15, max=100
# Length of issues: 100
# cxf Starting at: 7600, Max results: 100
# API call status: timeout=15, max=100
# Length of issues: 100
# cxf Starting at: 7700, Max results: 100
# API call status: timeout=15, max=100
# Length of issues: 100
# cxf Starting at: 7800, Max results: 100
# API call status: timeout=15, max=100
# Length of issues: 100
# cxf Starting at: 7900, Max results: 100
# API call status: timeout=15, max=100
# Length of issues: 100
# cxf Starting at: 8000, Max results: 100
# API call status: timeout=15, max=100
# Length of issues: 100
# cxf Starting at: 8100, Max results: 100
# API call status: timeout=15, max=100
# Length of issues: 100
# cxf Starting at: 8200, Max results: 100
# API call status: timeout=15, max=100
# Length of issues: 100
# cxf Starting at: 8300, Max results: 100
# API call status: timeout=15, max=100
# Length of issues: 100
# cxf Starting at: 8400, Max results: 100
# API call status: timeout=15, max=100
# Length of issues: 100
# cxf Starting at: 8500, Max results: 100
# API call status: timeout=15, max=100
# Length of issues: 100
# cxf Starting at: 8600, Max results: 100
# API call status: timeout=15, max=100
# Length of issues: 12
# cxf Starting at: 8700, Max results: 100
# cxf download completed!
# API call status: timeout=15, max=100
# Length of issues: 43
# cxfxjc Starting at: 0, Max results: 100
# cxfxjc download completed!
# API call status: timeout=15, max=100
# Length of issues: 100
# fediz Starting at: 0, Max results: 100
# API call status: timeout=15, max=100
# Length of issues: 100
# fediz Starting at: 100, Max results: 100
# API call status: timeout=15, max=100
# Length of issues: 53
# fediz Starting at: 200, Max results: 100
# fediz download completed!
# API call status: timeout=15, max=100
# Length of issues: 100
# daffodil Starting at: 0, Max results: 100
# API call status: timeout=15, max=100
# Length of issues: 100
# daffodil Starting at: 100, Max results: 100
# API call status: timeout=15, max=100
# Length of issues: 100
# daffodil Starting at: 200, Max results: 100
# API call status: timeout=15, max=100
# Length of issues: 100
# daffodil Starting at: 300, Max results: 100
# API call status: timeout=15, max=100
# Length of issues: 100
# daffodil Starting at: 400, Max results: 100
# API call status: timeout=15, max=100
# Length of issues: 100
# daffodil Starting at: 500, Max results: 100
# API call status: timeout=15, max=100
# Length of issues: 100
# daffodil Starting at: 600, Max results: 100
# API call status: timeout=15, max=100
# Length of issues: 100
# daffodil Starting at: 700, Max results: 100
# API call status: timeout=15, max=100
# Length of issues: 100
# daffodil Starting at: 800, Max results: 100
# API call status: timeout=15, max=100
# Length of issues: 100
# daffodil Starting at: 900, Max results: 100
# API call status: timeout=15, max=100
# Length of issues: 100
# daffodil Starting at: 1000, Max results: 100
# API call status: timeout=15, max=100
# Length of issues: 100
# daffodil Starting at: 1100, Max results: 100
# API call status: timeout=15, max=100
# Length of issues: 100
# daffodil Starting at: 1200, Max results: 100
# API call status: timeout=15, max=100
# Length of issues: 100
# daffodil Starting at: 1300, Max results: 100
# API call status: timeout=15, max=100
# Length of issues: 100
# daffodil Starting at: 1400, Max results: 100
# API call status: timeout=15, max=100
# Length of issues: 100
# daffodil Starting at: 1500, Max results: 100
# API call status: timeout=15, max=100
# Length of issues: 100
# daffodil Starting at: 1600, Max results: 100
# API call status: timeout=15, max=100
# Length of issues: 100
# daffodil Starting at: 1700, Max results: 100
# API call status: timeout=15, max=100
# Length of issues: 100
# daffodil Starting at: 1800, Max results: 100
# API call status: timeout=15, max=100
# Length of issues: 100
# daffodil Starting at: 1900, Max results: 100
# API call status: timeout=15, max=100
# Length of issues: 100
# daffodil Starting at: 2000, Max results: 100
# API call status: timeout=15, max=100
# Length of issues: 100
# daffodil Starting at: 2100, Max results: 100
# API call status: timeout=15, max=100
# Length of issues: 100
# daffodil Starting at: 2200, Max results: 100
# API call status: timeout=15, max=100
# Length of issues: 100
# daffodil Starting at: 2300, Max results: 100
# API call status: timeout=15, max=100
# Length of issues: 100
# daffodil Starting at: 2400, Max results: 100
# API call status: timeout=15, max=100
# Length of issues: 100
# daffodil Starting at: 2500, Max results: 100
# API call status: timeout=15, max=100
# Length of issues: 100
# daffodil Starting at: 2600, Max results: 100
# API call status: timeout=15, max=100
# Length of issues: 52
# daffodil Starting at: 2700, Max results: 100
# daffodil download completed!
# API call status: timeout=15, max=100
# Length of issues: 100
# datafu Starting at: 0, Max results: 100
# API call status: timeout=15, max=100
# Length of issues: 71
# datafu Starting at: 100, Max results: 100
# datafu download completed!
# API call status: timeout=15, max=100
# Length of issues: 67
# daytrader Starting at: 0, Max results: 100
# daytrader download completed!
# API call status: timeout=15, max=100
# Length of issues: 100
# ddlutils Starting at: 0, Max results: 100
# API call status: timeout=15, max=100
# Length of issues: 100
# ddlutils Starting at: 100, Max results: 100
# API call status: timeout=15, max=100
# Length of issues: 89
# ddlutils Starting at: 200, Max results: 100
# ddlutils download completed!
# API call status: timeout=15, max=100
# Length of issues: 100
# dtacloud Starting at: 0, Max results: 100
# API call status: timeout=15, max=100
# Length of issues: 100
# dtacloud Starting at: 100, Max results: 100
# API call status: timeout=15, max=100
# Length of issues: 100
# dtacloud Starting at: 200, Max results: 100
# API call status: timeout=15, max=100
# Length of issues: 100
# dtacloud Starting at: 300, Max results: 100
# API call status: timeout=15, max=100
# Length of issues: 100
# dtacloud Starting at: 400, Max results: 100
# API call status: timeout=15, max=100
# Length of issues: 87
# dtacloud Starting at: 500, Max results: 100
# dtacloud download completed!
# API call status: timeout=15, max=100
# Length of issues: 100
# deltaspike Starting at: 0, Max results: 100
# API call status: timeout=15, max=100
# Length of issues: 100
# deltaspike Starting at: 100, Max results: 100
# API call status: timeout=15, max=100
# Length of issues: 100
# deltaspike Starting at: 200, Max results: 100
# API call status: timeout=15, max=100
# Length of issues: 100
# deltaspike Starting at: 300, Max results: 100
# API call status: timeout=15, max=100
# Length of issues: 100
# deltaspike Starting at: 400, Max results: 100
# API call status: timeout=15, max=100
# Length of issues: 100
# deltaspike Starting at: 500, Max results: 100
# API call status: timeout=15, max=100
# Length of issues: 100
# deltaspike Starting at: 600, Max results: 100
# API call status: timeout=15, max=100
# Length of issues: 100
# deltaspike Starting at: 700, Max results: 100
# API call status: timeout=15, max=100
# Length of issues: 100
# deltaspike Starting at: 800, Max results: 100
# API call status: timeout=15, max=100
# Length of issues: 100
# deltaspike Starting at: 900, Max results: 100
# API call status: timeout=15, max=100
# Length of issues: 100
# deltaspike Starting at: 1000, Max results: 100
# API call status: timeout=15, max=100
# Length of issues: 100
# deltaspike Starting at: 1100, Max results: 100
# API call status: timeout=15, max=100
# Length of issues: 100
# deltaspike Starting at: 1200, Max results: 100
# API call status: timeout=15, max=100
# Length of issues: 89
# deltaspike Starting at: 1300, Max results: 100
# deltaspike download completed!
# API call status: timeout=15, max=100
# Length of issues: 100
# derby Starting at: 0, Max results: 100
# API call status: timeout=15, max=100
# Length of issues: 100
# derby Starting at: 100, Max results: 100
# API call status: timeout=15, max=100
# Length of issues: 100
# derby Starting at: 200, Max results: 100
# API call status: timeout=15, max=100
# Length of issues: 100
# derby Starting at: 300, Max results: 100
# API call status: timeout=15, max=100
# Length of issues: 100
# derby Starting at: 400, Max results: 100
# API call status: timeout=15, max=100
# Length of issues: 100
# derby Starting at: 500, Max results: 100
# API call status: timeout=15, max=100
# Length of issues: 100
# derby Starting at: 600, Max results: 100
# API call status: timeout=15, max=100
# Length of issues: 100
# derby Starting at: 700, Max results: 100
# API call status: timeout=15, max=100
# Length of issues: 100
# derby Starting at: 800, Max results: 100
# API call status: timeout=15, max=100
# Length of issues: 100
# derby Starting at: 900, Max results: 100
# API call status: timeout=15, max=100
# Length of issues: 100
# derby Starting at: 1000, Max results: 100
# API call status: timeout=15, max=100
# Length of issues: 100
# derby Starting at: 1100, Max results: 100
# API call status: timeout=15, max=100
# Length of issues: 100
# derby Starting at: 1200, Max results: 100
# API call status: timeout=15, max=100
# Length of issues: 100
# derby Starting at: 1300, Max results: 100
# API call status: timeout=15, max=100
# Length of issues: 100
# derby Starting at: 1400, Max results: 100
# API call status: timeout=15, max=100
# Length of issues: 100
# derby Starting at: 1500, Max results: 100
# API call status: timeout=15, max=100
# Length of issues: 100
# derby Starting at: 1600, Max results: 100
# API call status: timeout=15, max=100
# Length of issues: 100
# derby Starting at: 1700, Max results: 100
# API call status: timeout=15, max=100
# Length of issues: 100
# derby Starting at: 1800, Max results: 100
# API call status: timeout=15, max=100
# Length of issues: 100
# derby Starting at: 1900, Max results: 100
# API call status: timeout=15, max=100
# Length of issues: 100
# derby Starting at: 2000, Max results: 100
# API call status: timeout=15, max=100
# Length of issues: 100
# derby Starting at: 2100, Max results: 100
# API call status: timeout=15, max=100
# Length of issues: 100
# derby Starting at: 2200, Max results: 100
# API call status: timeout=15, max=100
# Length of issues: 100
# derby Starting at: 2300, Max results: 100
# API call status: timeout=15, max=100
# Length of issues: 100
# derby Starting at: 2400, Max results: 100
# API call status: timeout=15, max=100
# Length of issues: 100
# derby Starting at: 2500, Max results: 100
# API call status: timeout=15, max=100
# Length of issues: 100
# derby Starting at: 2600, Max results: 100
# API call status: timeout=15, max=100
# Length of issues: 100
# derby Starting at: 2700, Max results: 100
# API call status: timeout=15, max=100
# Length of issues: 100
# derby Starting at: 2800, Max results: 100
# API call status: timeout=15, max=100
# Length of issues: 100
# derby Starting at: 2900, Max results: 100
# API call status: timeout=15, max=100
# Length of issues: 100
# derby Starting at: 3000, Max results: 100
# API call status: timeout=15, max=100
# Length of issues: 100
# derby Starting at: 3100, Max results: 100
# API call status: timeout=15, max=100
# Length of issues: 100
# derby Starting at: 3200, Max results: 100
# API call status: timeout=15, max=100
# Length of issues: 100
# derby Starting at: 3300, Max results: 100
# API call status: timeout=15, max=100
# Length of issues: 100
# derby Starting at: 3400, Max results: 100
# API call status: timeout=15, max=100
# Length of issues: 100
# derby Starting at: 3500, Max results: 100
# API call status: timeout=15, max=100
# Length of issues: 100
# derby Starting at: 3600, Max results: 100
# API call status: timeout=15, max=100
# Length of issues: 100
# derby Starting at: 3700, Max results: 100
# API call status: timeout=15, max=100
# Length of issues: 100
# derby Starting at: 3800, Max results: 100
# API call status: timeout=15, max=100
# Length of issues: 100
# derby Starting at: 3900, Max results: 100
# API call status: timeout=15, max=100
# Length of issues: 100
# derby Starting at: 4000, Max results: 100
# API call status: timeout=15, max=100
# Length of issues: 100
# derby Starting at: 4100, Max results: 100
# API call status: timeout=15, max=100
# Length of issues: 100
# derby Starting at: 4200, Max results: 100
# API call status: timeout=15, max=100
# Length of issues: 100
# derby Starting at: 4300, Max results: 100
# API call status: timeout=15, max=100
# Length of issues: 100
# derby Starting at: 4400, Max results: 100
# API call status: timeout=15, max=100
# Length of issues: 100
# derby Starting at: 4500, Max results: 100
# API call status: timeout=15, max=100
# Length of issues: 100
# derby Starting at: 4600, Max results: 100
# API call status: timeout=15, max=100
# Length of issues: 100
# derby Starting at: 4700, Max results: 100
# API call status: timeout=15, max=100
# Length of issues: 100
# derby Starting at: 4800, Max results: 100
# API call status: timeout=15, max=100
# Length of issues: 100
# derby Starting at: 4900, Max results: 100
# API call status: timeout=15, max=100
# Length of issues: 100
# derby Starting at: 5000, Max results: 100
# API call status: timeout=15, max=100
# Length of issues: 100
# derby Starting at: 5100, Max results: 100
# API call status: timeout=15, max=100
# Length of issues: 100
# derby Starting at: 5200, Max results: 100
# API call status: timeout=15, max=100
# Length of issues: 100
# derby Starting at: 5300, Max results: 100
# API call status: timeout=15, max=100
# Length of issues: 100
# derby Starting at: 5400, Max results: 100
# API call status: timeout=15, max=100
# Length of issues: 100
# derby Starting at: 5500, Max results: 100
# API call status: timeout=15, max=100
# Length of issues: 100
# derby Starting at: 5600, Max results: 100
# API call status: timeout=15, max=100
# Length of issues: 100
# derby Starting at: 5700, Max results: 100
# API call status: timeout=15, max=100
# Length of issues: 100
# derby Starting at: 5800, Max results: 100
# API call status: timeout=15, max=100
# Length of issues: 100
# derby Starting at: 5900, Max results: 100
# API call status: timeout=15, max=100
# Length of issues: 100
# derby Starting at: 6000, Max results: 100
# API call status: timeout=15, max=100
# Length of issues: 100
# derby Starting at: 6100, Max results: 100
# API call status: timeout=15, max=100
# Length of issues: 100
# derby Starting at: 6200, Max results: 100
# API call status: timeout=15, max=100
# Length of issues: 100
# derby Starting at: 6300, Max results: 100
# API call status: timeout=15, max=100
# Length of issues: 100
# derby Starting at: 6400, Max results: 100
# API call status: timeout=15, max=100
# Length of issues: 100
# derby Starting at: 6500, Max results: 100
# API call status: timeout=15, max=100
# Length of issues: 100
# derby Starting at: 6600, Max results: 100
# API call status: timeout=15, max=100
# Length of issues: 100
# derby Starting at: 6700, Max results: 100
# API call status: timeout=15, max=100
# Length of issues: 100
# derby Starting at: 6800, Max results: 100
# API call status: timeout=15, max=100
# Length of issues: 100
# derby Starting at: 6900, Max results: 100
# API call status: timeout=15, max=100
# Length of issues: 100
# derby Starting at: 7000, Max results: 100
# API call status: timeout=15, max=100
# Length of issues: 41
# derby Starting at: 7100, Max results: 100
# derby download completed!
# API call status: timeout=15, max=100
# Length of issues: 100
# dmap Starting at: 0, Max results: 100
# API call status: timeout=15, max=100
# Length of issues: 100
# dmap Starting at: 100, Max results: 100
# API call status: timeout=15, max=100
# Length of issues: 4
# dmap Starting at: 200, Max results: 100
# dmap download completed!
# API call status: timeout=15, max=100
# Length of issues: 100
# dir Starting at: 0, Max results: 100
# API call status: timeout=15, max=100
# Length of issues: 100
# dir Starting at: 100, Max results: 100
# API call status: timeout=15, max=100
# Length of issues: 27
# dir Starting at: 200, Max results: 100
# dir download completed!
# API call status: timeout=15, max=100
# Length of issues: 100
# dirserver Starting at: 0, Max results: 100
# API call status: timeout=15, max=100
# Length of issues: 100
# dirserver Starting at: 100, Max results: 100
# API call status: timeout=15, max=100
# Length of issues: 100
# dirserver Starting at: 200, Max results: 100
# API call status: timeout=15, max=100
# Length of issues: 100
# dirserver Starting at: 300, Max results: 100
# API call status: timeout=15, max=100
# Length of issues: 100
# dirserver Starting at: 400, Max results: 100
# API call status: timeout=15, max=100
# Length of issues: 100
# dirserver Starting at: 500, Max results: 100
# API call status: timeout=15, max=100
# Length of issues: 100
# dirserver Starting at: 600, Max results: 100
# API call status: timeout=15, max=100
# Length of issues: 100
# dirserver Starting at: 700, Max results: 100
# API call status: timeout=15, max=100
# Length of issues: 100
# dirserver Starting at: 800, Max results: 100
# API call status: timeout=15, max=100
# Length of issues: 100
# dirserver Starting at: 900, Max results: 100
# API call status: timeout=15, max=100
# Length of issues: 100
# dirserver Starting at: 1000, Max results: 100
# API call status: timeout=15, max=100
# Length of issues: 100
# dirserver Starting at: 1100, Max results: 100
# API call status: timeout=15, max=100
# Length of issues: 100
# dirserver Starting at: 1200, Max results: 100
# API call status: timeout=15, max=100
# Length of issues: 100
# dirserver Starting at: 1300, Max results: 100
# API call status: timeout=15, max=100
# Length of issues: 100
# dirserver Starting at: 1400, Max results: 100
# API call status: timeout=15, max=100
# Length of issues: 100
# dirserver Starting at: 1500, Max results: 100
# API call status: timeout=15, max=100
# Length of issues: 100
# dirserver Starting at: 1600, Max results: 100
# API call status: timeout=15, max=100
# Length of issues: 100
# dirserver Starting at: 1700, Max results: 100
# API call status: timeout=15, max=100
# Length of issues: 100
# dirserver Starting at: 1800, Max results: 100
# API call status: timeout=15, max=100
# Length of issues: 100
# dirserver Starting at: 1900, Max results: 100
# API call status: timeout=15, max=100
# Length of issues: 100
# dirserver Starting at: 2000, Max results: 100
# API call status: timeout=15, max=100
# Length of issues: 100
# dirserver Starting at: 2100, Max results: 100
# API call status: timeout=15, max=100
# Length of issues: 94
# dirserver Starting at: 2200, Max results: 100
# dirserver download completed!
# API call status: timeout=15, max=100
# Length of issues: 100
# dirapi Starting at: 0, Max results: 100
# API call status: timeout=15, max=100
# Length of issues: 100
# dirapi Starting at: 100, Max results: 100
# API call status: timeout=15, max=100
# Length of issues: 100
# dirapi Starting at: 200, Max results: 100
# API call status: timeout=15, max=100
# Length of issues: 63
# dirapi Starting at: 300, Max results: 100
# dirapi download completed!
# API call status: timeout=15, max=100
# Length of issues: 9
# dirgroovy Starting at: 0, Max results: 100
# dirgroovy download completed!
# API call status: timeout=15, max=100
# Length of issues: 100
# dirkrb Starting at: 0, Max results: 100
# API call status: timeout=15, max=100
# Length of issues: 100
# dirkrb Starting at: 100, Max results: 100
# API call status: timeout=15, max=100
# Length of issues: 100
# dirkrb Starting at: 200, Max results: 100
# API call status: timeout=15, max=100
# Length of issues: 100
# dirkrb Starting at: 300, Max results: 100
# API call status: timeout=15, max=100
# Length of issues: 100
# dirkrb Starting at: 400, Max results: 100
# API call status: timeout=15, max=100
# Length of issues: 100
# dirkrb Starting at: 500, Max results: 100
# API call status: timeout=15, max=100
# Length of issues: 100
# dirkrb Starting at: 600, Max results: 100
# API call status: timeout=15, max=100
# Length of issues: 55
# dirkrb Starting at: 700, Max results: 100
# dirkrb download completed!
# API call status: timeout=15, max=100
# Length of issues: 15
# dirnaming Starting at: 0, Max results: 100
# dirnaming download completed!
# API call status: timeout=15, max=100
# Length of issues: 100
# dirshared Starting at: 0, Max results: 100
# API call status: timeout=15, max=100
# Length of issues: 20
# dirshared Starting at: 100, Max results: 100
# dirshared download completed!
# API call status: timeout=15, max=100
# Length of issues: 100
# dirstudio Starting at: 0, Max results: 100
# API call status: timeout=15, max=100
# Length of issues: 100
# dirstudio Starting at: 100, Max results: 100
# API call status: timeout=15, max=100
# Length of issues: 100
# dirstudio Starting at: 200, Max results: 100
# API call status: timeout=15, max=100
# Length of issues: 100
# dirstudio Starting at: 300, Max results: 100
# API call status: timeout=15, max=100
# Length of issues: 100
# dirstudio Starting at: 400, Max results: 100
# API call status: timeout=15, max=100
# Length of issues: 100
# dirstudio Starting at: 500, Max results: 100
# API call status: timeout=15, max=100
# Length of issues: 100
# dirstudio Starting at: 600, Max results: 100
# API call status: timeout=15, max=100
# Length of issues: 100
# dirstudio Starting at: 700, Max results: 100
# API call status: timeout=15, max=100
# Length of issues: 100
# dirstudio Starting at: 800, Max results: 100
# ...
# Length of issues: 100
# xercesj Starting at: 400, Max results: 100
# API call status: timeout=15, max=100
# Length of issues: 100
# xercesj Starting at: 500, Max results: 100
# API call status: timeout=15, max=100
# Length of issues: 100
# xercesj Starting at: 600, Max results: 100
# API call status: timeout=15, max=100
# Length of issues: 100
# xercesj Starting at: 700, Max results: 100
# API call status: timeout=15, max=100
# Length of issues: 100
# xercesj Starting at: 800, Max results: 100
# API call status: timeout=15, max=100
# Length of issues: 100
# xercesj Starting at: 900, Max results: 100
# API call status: timeout=15, max=100
# Length of issues: 100
# xercesj Starting at: 1000, Max results: 100
# API call status: timeout=15, max=100
# Length of issues: 100
# xercesj Starting at: 1100, Max results: 100
# API call status: timeout=15, max=100
# Length of issues: 100
# xercesj Starting at: 1200, Max results: 100
# API call status: timeout=15, max=100
# Length of issues: 100
# xercesj Starting at: 1300, Max results: 100
# API call status: timeout=15, max=100
# Length of issues: 100
# xercesj Starting at: 1400, Max results: 100
# API call status: timeout=15, max=100
# Length of issues: 100
# xercesj Starting at: 1500, Max results: 100
# API call status: timeout=15, max=100
# Length of issues: 100
# xercesj Starting at: 1600, Max results: 100
# API call status: timeout=15, max=100
# Length of issues: 46
# xercesj Starting at: 1700, Max results: 100
# xercesj download completed!
# API call status: timeout=15, max=100
# Length of issues: 92
# xmlcommons Starting at: 0, Max results: 100
# xmlcommons download completed!
# API call status: timeout=15, max=100
# Length of issues: 100
# xmlbeans Starting at: 0, Max results: 100
# API call status: timeout=15, max=100
# Length of issues: 100
# xmlbeans Starting at: 100, Max results: 100
# API call status: timeout=15, max=100
# Length of issues: 100
# xmlbeans Starting at: 200, Max results: 100
# API call status: timeout=15, max=100
# Length of issues: 100
# xmlbeans Starting at: 300, Max results: 100
# API call status: timeout=15, max=100
# Length of issues: 100
# xmlbeans Starting at: 400, Max results: 100
# API call status: timeout=15, max=100
# Length of issues: 100
# xmlbeans Starting at: 500, Max results: 100
# API call status: timeout=15, max=100
# Length of issues: 28
# xmlbeans Starting at: 600, Max results: 100
# xmlbeans download completed!
# API call status: timeout=15, max=100
# Length of issues: 64
# xmlschema Starting at: 0, Max results: 100
# xmlschema download completed!
# API call status: timeout=15, max=100
# Length of issues: 100
# xw Starting at: 0, Max results: 100
# API call status: timeout=15, max=100
# Length of issues: 100
# xw Starting at: 100, Max results: 100
# API call status: timeout=15, max=100
# Length of issues: 100
# xw Starting at: 200, Max results: 100
# API call status: timeout=15, max=100
# Length of issues: 100
# xw Starting at: 300, Max results: 100
# API call status: timeout=15, max=100
# Length of issues: 100
# xw Starting at: 400, Max results: 100
# API call status: timeout=15, max=100
# Length of issues: 100
# xw Starting at: 500, Max results: 100
# API call status: timeout=15, max=100
# Length of issues: 100
# xw Starting at: 600, Max results: 100
# API call status: timeout=15, max=100
# Length of issues: 100
# xw Starting at: 700, Max results: 100
# API call status: timeout=15, max=100
# Length of issues: 100
# xw Starting at: 800, Max results: 100
# API call status: timeout=15, max=100
# Length of issues: 100
# xw Starting at: 900, Max results: 100
# API call status: timeout=15, max=100
# Length of issues: 100
# xw Starting at: 1000, Max results: 100
# API call status: timeout=15, max=100
# Length of issues: 28
# xw Starting at: 1100, Max results: 100
# xw download completed!
# API call status: timeout=15, max=100
# Length of issues: 100
# yetus Starting at: 0, Max results: 100
# API call status: timeout=15, max=100
# Length of issues: 100
# yetus Starting at: 100, Max results: 100
# API call status: timeout=15, max=100
# Length of issues: 100
# yetus Starting at: 200, Max results: 100
# API call status: timeout=15, max=100
# Length of issues: 100
# yetus Starting at: 300, Max results: 100
# API call status: timeout=15, max=100
# Length of issues: 100
# yetus Starting at: 400, Max results: 100
# API call status: timeout=15, max=100
# Length of issues: 100
# yetus Starting at: 500, Max results: 100
# API call status: timeout=15, max=100
# Length of issues: 100
# yetus Starting at: 600, Max results: 100
# API call status: timeout=15, max=100
# Length of issues: 100
# yetus Starting at: 700, Max results: 100
# API call status: timeout=15, max=100
# Length of issues: 100
# yetus Starting at: 800, Max results: 100
# API call status: timeout=15, max=100
# Length of issues: 100
# yetus Starting at: 900, Max results: 100
# API call status: timeout=15, max=100
# Length of issues: 100
# yetus Starting at: 1000, Max results: 100
# API call status: timeout=15, max=100
# Length of issues: 100
# yetus Starting at: 1100, Max results: 100
# yetus download completed!
# yoko download completed!
# API call status: timeout=15, max=100
# Length of issues: 100
# zeppelin Starting at: 0, Max results: 100
# API call status: timeout=15, max=100
# Length of issues: 100
# zeppelin Starting at: 100, Max results: 100
# API call status: timeout=15, max=100
# Length of issues: 100
# zeppelin Starting at: 200, Max results: 100
# API call status: timeout=15, max=100
# Length of issues: 100
# zeppelin Starting at: 300, Max results: 100
# API call status: timeout=15, max=100
# Length of issues: 100
# zeppelin Starting at: 400, Max results: 100
# API call status: timeout=15, max=100
# Length of issues: 100
# zeppelin Starting at: 500, Max results: 100
# API call status: timeout=15, max=100
# Length of issues: 100
# zeppelin Starting at: 600, Max results: 100
# API call status: timeout=15, max=100
# Length of issues: 100
# zeppelin Starting at: 700, Max results: 100
# API call status: timeout=15, max=100
# Length of issues: 100
# zeppelin Starting at: 800, Max results: 100
# API call status: timeout=15, max=100
# Length of issues: 100
# zeppelin Starting at: 900, Max results: 100
# API call status: timeout=15, max=100
# Length of issues: 100
# zeppelin Starting at: 1000, Max results: 100
# API call status: timeout=15, max=100
# Length of issues: 100
# zeppelin Starting at: 1100, Max results: 100
# API call status: timeout=15, max=100
# Length of issues: 100
# zeppelin Starting at: 1200, Max results: 100
# API call status: timeout=15, max=100
# Length of issues: 100
# zeppelin Starting at: 1300, Max results: 100
# API call status: timeout=15, max=100
# Length of issues: 100
# zeppelin Starting at: 1400, Max results: 100
# API call status: timeout=15, max=100
# Length of issues: 100
# zeppelin Starting at: 1500, Max results: 100
# API call status: timeout=15, max=100
# Length of issues: 100
# zeppelin Starting at: 1600, Max results: 100
# API call status: timeout=15, max=100
# Length of issues: 100
# zeppelin Starting at: 1700, Max results: 100
# API call status: timeout=15, max=100
# Length of issues: 100
# zeppelin Starting at: 1800, Max results: 100
# API call status: timeout=15, max=100
# Length of issues: 100
# zeppelin Starting at: 1900, Max results: 100
# API call status: timeout=15, max=100
# Length of issues: 100
# zeppelin Starting at: 2000, Max results: 100
# API call status: timeout=15, max=100
# Length of issues: 100
# zeppelin Starting at: 2100, Max results: 100
# API call status: timeout=15, max=100
# Length of issues: 100
# zeppelin Starting at: 2200, Max results: 100
# API call status: timeout=15, max=100
# Length of issues: 100
# zeppelin Starting at: 2300, Max results: 100
# API call status: timeout=15, max=100
# Length of issues: 100
# zeppelin Starting at: 2400, Max results: 100
# API call status: timeout=15, max=100
# Length of issues: 100
# zeppelin Starting at: 2500, Max results: 100
# API call status: timeout=15, max=100
# Length of issues: 100
# zeppelin Starting at: 2600, Max results: 100
# API call status: timeout=15, max=100
# Length of issues: 100
# zeppelin Starting at: 2700, Max results: 100
# API call status: timeout=15, max=100
# Length of issues: 100
# zeppelin Starting at: 2800, Max results: 100
# API call status: timeout=15, max=100
# Length of issues: 100
# zeppelin Starting at: 2900, Max results: 100
# API call status: timeout=15, max=100
# Length of issues: 100
# zeppelin Starting at: 3000, Max results: 100
# API call status: timeout=15, max=100
# Length of issues: 100
# zeppelin Starting at: 3100, Max results: 100
# API call status: timeout=15, max=100
# Length of issues: 100
# zeppelin Starting at: 3200, Max results: 100
# API call status: timeout=15, max=100
# Length of issues: 100
# zeppelin Starting at: 3300, Max results: 100
# API call status: timeout=15, max=100
# Length of issues: 100
# zeppelin Starting at: 3400, Max results: 100
# API call status: timeout=15, max=100
# Length of issues: 100
# zeppelin Starting at: 3500, Max results: 100
# API call status: timeout=15, max=100
# Length of issues: 100
# zeppelin Starting at: 3600, Max results: 100
# API call status: timeout=15, max=100
# Length of issues: 100
# zeppelin Starting at: 3700, Max results: 100
# API call status: timeout=15, max=100
# Length of issues: 100
# zeppelin Starting at: 3800, Max results: 100
# API call status: timeout=15, max=100
# Length of issues: 100
# zeppelin Starting at: 3900, Max results: 100
# API call status: timeout=15, max=100
# Length of issues: 100
# zeppelin Starting at: 4000, Max results: 100
# API call status: timeout=15, max=100
# Length of issues: 100
# zeppelin Starting at: 4100, Max results: 100
# API call status: timeout=15, max=100
# Length of issues: 100
# zeppelin Starting at: 4200, Max results: 100
# API call status: timeout=15, max=100
# Length of issues: 100
# zeppelin Starting at: 4300, Max results: 100
# API call status: timeout=15, max=100
# Length of issues: 100
# zeppelin Starting at: 4400, Max results: 100
# API call status: timeout=15, max=100
# Length of issues: 100
# zeppelin Starting at: 4500, Max results: 100
# API call status: timeout=15, max=100
# Length of issues: 100
# zeppelin Starting at: 4600, Max results: 100
# API call status: timeout=15, max=100
# Length of issues: 100
# zeppelin Starting at: 4700, Max results: 100
# API call status: timeout=15, max=100
# Length of issues: 100
# zeppelin Starting at: 4800, Max results: 100
# API call status: timeout=15, max=100
# Length of issues: 100
# zeppelin Starting at: 4900, Max results: 100
# API call status: timeout=15, max=100
# Length of issues: 100
# zeppelin Starting at: 5000, Max results: 100
# API call status: timeout=15, max=100
# Length of issues: 100
# zeppelin Starting at: 5100, Max results: 100
# API call status: timeout=15, max=100
# Length of issues: 100
# zeppelin Starting at: 5200, Max results: 100
# API call status: timeout=15, max=100
# Length of issues: 100
# zeppelin Starting at: 5300, Max results: 100
# API call status: timeout=15, max=100
# Length of issues: 100
# zeppelin Starting at: 5400, Max results: 100
# API call status: timeout=15, max=100
# Length of issues: 100
# zeppelin Starting at: 5500, Max results: 100
# API call status: timeout=15, max=100
# Length of issues: 100
# zeppelin Starting at: 5600, Max results: 100
# API call status: timeout=15, max=100
# Length of issues: 100
# zeppelin Starting at: 5700, Max results: 100
# API call status: timeout=15, max=100
# Length of issues: 70
# zeppelin Starting at: 5800, Max results: 100
# zeppelin download completed!
# API call status: timeout=15, max=100
# Length of issues: 100
# zetacomp Starting at: 0, Max results: 100
# API call status: timeout=15, max=100
# Length of issues: 23
# zetacomp Starting at: 100, Max results: 100
# zetacomp download completed!
# API call status: timeout=15, max=100
# Length of issues: 100
# zookeeper Starting at: 0, Max results: 100
# API call status: timeout=15, max=100
# Length of issues: 100
# zookeeper Starting at: 100, Max results: 100
# API call status: timeout=15, max=100
# Length of issues: 100
# zookeeper Starting at: 200, Max results: 100
# API call status: timeout=15, max=100
# Length of issues: 100
# zookeeper Starting at: 300, Max results: 100
# API call status: timeout=15, max=100
# Length of issues: 100
# zookeeper Starting at: 400, Max results: 100
# API call status: timeout=15, max=100
# Length of issues: 100
# zookeeper Starting at: 500, Max results: 100
# API call status: timeout=15, max=100
# Length of issues: 100
# zookeeper Starting at: 600, Max results: 100
# API call status: timeout=15, max=100
# Length of issues: 100
# zookeeper Starting at: 700, Max results: 100
# API call status: timeout=15, max=100
# Length of issues: 100
# zookeeper Starting at: 800, Max results: 100
# API call status: timeout=15, max=100
# Length of issues: 100
# zookeeper Starting at: 900, Max results: 100
# API call status: timeout=15, max=100
# Length of issues: 100
# zookeeper Starting at: 1000, Max results: 100
# API call status: timeout=15, max=100
# Length of issues: 100
# zookeeper Starting at: 1100, Max results: 100
# API call status: timeout=15, max=100
# Length of issues: 100
# zookeeper Starting at: 1200, Max results: 100
# API call status: timeout=15, max=100
# Length of issues: 100
# zookeeper Starting at: 1300, Max results: 100
# API call status: timeout=15, max=100
# Length of issues: 100
# zookeeper Starting at: 1400, Max results: 100
# API call status: timeout=15, max=100
# Length of issues: 100
# zookeeper Starting at: 1500, Max results: 100
# API call status: timeout=15, max=100
# Length of issues: 100
# zookeeper Starting at: 1600, Max results: 100
# API call status: timeout=15, max=100
# Length of issues: 100
# zookeeper Starting at: 1700, Max results: 100
# API call status: timeout=15, max=100
# Length of issues: 100
# zookeeper Starting at: 1800, Max results: 100
# API call status: timeout=15, max=100
# Length of issues: 100
# zookeeper Starting at: 1900, Max results: 100
# API call status: timeout=15, max=100
# Length of issues: 100
# zookeeper Starting at: 2000, Max results: 100
# API call status: timeout=15, max=100
# Length of issues: 100
# zookeeper Starting at: 2100, Max results: 100
# API call status: timeout=15, max=100
# Length of issues: 100
# zookeeper Starting at: 2200, Max results: 100
# API call status: timeout=15, max=100
# Length of issues: 100
# zookeeper Starting at: 2300, Max results: 100
# API call status: timeout=15, max=100
# Length of issues: 100
# zookeeper Starting at: 2400, Max results: 100
# API call status: timeout=15, max=100
# Length of issues: 100
# zookeeper Starting at: 2500, Max results: 100
# API call status: timeout=15, max=100
# Length of issues: 100
# zookeeper Starting at: 2600, Max results: 100
# API call status: timeout=15, max=100
# Length of issues: 100
# zookeeper Starting at: 2700, Max results: 100
# API call status: timeout=15, max=100
# Length of issues: 100
# zookeeper Starting at: 2800, Max results: 100
# API call status: timeout=15, max=100
# Length of issues: 100
# zookeeper Starting at: 2900, Max results: 100
# API call status: timeout=15, max=100
# Length of issues: 100
# zookeeper Starting at: 3000, Max results: 100
# API call status: timeout=15, max=100
# Length of issues: 100
# zookeeper Starting at: 3100, Max results: 100
# API call status: timeout=15, max=100
# Length of issues: 100
# zookeeper Starting at: 3200, Max results: 100
# API call status: timeout=15, max=100
# Length of issues: 100
# zookeeper Starting at: 3300, Max results: 100
# API call status: timeout=15, max=100
# Length of issues: 100
# zookeeper Starting at: 3400, Max results: 100
# API call status: timeout=15, max=100
# Length of issues: 100
# zookeeper Starting at: 3500, Max results: 100
# API call status: timeout=15, max=100
# Length of issues: 100
# zookeeper Starting at: 3600, Max results: 100
# API call status: timeout=15, max=100
# Length of issues: 100
# zookeeper Starting at: 3700, Max results: 100
# API call status: timeout=15, max=100
# Length of issues: 100
# zookeeper Starting at: 3800, Max results: 100
# API call status: timeout=15, max=100
# Length of issues: 100
# zookeeper Starting at: 3900, Max results: 100
# API call status: timeout=15, max=100
# Length of issues: 100
# zookeeper Starting at: 4000, Max results: 100
# API call status: timeout=15, max=100
# Length of issues: 100
# zookeeper Starting at: 4100, Max results: 100
# API call status: timeout=15, max=100
# Length of issues: 100
# zookeeper Starting at: 4200, Max results: 100
# API call status: timeout=15, max=100
# Length of issues: 100
# zookeeper Starting at: 4300, Max results: 100
# API call status: timeout=15, max=100
# Length of issues: 80
# zookeeper Starting at: 4400, Max results: 100
# zookeeper download completed!
